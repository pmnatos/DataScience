# %% [markdown]
# # Association Rules
#
# #### In this section, we will learn about how to use assocition rules in python and how to filter data based on different metrics of association rules.
#
#
# Following libraries are used for association rules:
# - pandas
# - numpy
# - matplotlib
# - mlxtend

# %%
# Import necessary modules

import numpy as np
import pandas as pd
import csv
from matplotlib import pyplot as plt

# Import FP-growth and Apriori modules, TransactionEncoder module and association module from mlxtend

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules as arule
from mlxtend.frequent_patterns import fpgrowth

# %% [markdown]
# ### Read data from Repair.csv
#
# We use Repair.csv file as a data set for finding frequent item sets. FP-growth and Apriori algorithms are used for finding frequent itemsets.

# %%
# Read file 'Repair.csv' and change the data format for applying algorithms

data_set = []

with open("Repair.csv") as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        data_set.append(row)

# %% [markdown]
# ### FP-grwoth algorithm
#
# We use Repair.csv file as a data set for finding frequent item sets. FP-growth algorithm is used for finding frequent itemsets.

# %%
# learn to use TransactionEncoder module to convert an array to DataFrame for FP-growth algorithm in mlxtend

te = TransactionEncoder()
te_ary = te.fit(data_set).transform(data_set)
data = pd.DataFrame(te_ary, columns = te.columns_)
data.tail(5)
# Out:
#       Analyze Defect  Archive Repair  Inform User  Register  Repair (Complex)  \
# 1099            True            True         True      True              True
# 1100            True            True         True      True              True
# 1101            True            True         True      True              True
# 1102            True            True         True      True              True
# 1103            True            True         True      True             False
#
#       Repair (Simple)  Restart Repair  Test Repair
# 1099            False           False         True
# 1100            False           False         True
# 1101            False           False         True
# 1102            False           False         True
# 1103             True            True         True

# %%
frequent_itemsets=fpgrowth(data, min_support=0.3, use_colnames=True)
print(frequent_itemsets)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets_filtered = frequent_itemsets.loc[(frequent_itemsets['length'] > 3) & (frequent_itemsets['support'] > 0.3)]   
frequent_itemsets_filtered
# Out:
#      support                                           itemsets
# 0   1.000000                                         (Register)
# 1   1.000000                                   (Analyze Defect)
# 2   0.998188                                      (Test Repair)
# 3   0.998188                                      (Inform User)
# 4   0.905797                                   (Archive Repair)
# ..       ...                                                ...
# 90  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...
# 91  0.386775  (Test Repair, Repair (Simple), Inform User, Ar...
# 92  0.386775  (Analyze Defect, Repair (Simple), Archive Repa...
# 93  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...
# 94  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...
#
# [95 rows x 2 columns]
#      support                                           itemsets  length
# 17  0.998188  (Inform User, Register, Analyze Defect, Test R...       4
# 28  0.905797  (Inform User, Analyze Defect, Test Repair, Arc...       4
# 29  0.905797  (Register, Inform User, Test Repair, Archive R...       4
# 30  0.905797  (Inform User, Register, Analyze Defect, Archiv...       4
# 31  0.905797  (Register, Analyze Defect, Test Repair, Archiv...       4
# 32  0.905797  (Analyze Defect, Test Repair, Archive Repair, ...       5
# 48  0.595109  (Inform User, Register, Analyze Defect, Repair...       4
# 49  0.595109  (Register, Test Repair, Analyze Defect, Repair...       4
# 50  0.550725  (Register, Analyze Defect, Repair (Complex), A...       4
# 51  0.595109  (Inform User, Test Repair, Analyze Defect, Rep...       4
# 52  0.550725  (Inform User, Analyze Defect, Repair (Complex)...       4
# 53  0.550725  (Test Repair, Analyze Defect, Repair (Complex)...       4
# 54  0.595109  (Register, Test Repair, Inform User, Repair (C...       4
# 55  0.550725  (Register, Inform User, Repair (Complex), Arch...       4
# 56  0.550725  (Test Repair, Register, Repair (Complex), Arch...       4
# 57  0.550725  (Test Repair, Inform User, Repair (Complex), A...       4
# 58  0.595109  (Analyze Defect, Test Repair, Repair (Complex)...       5
# 59  0.550725  (Analyze Defect, Repair (Complex), Archive Rep...       5
# 60  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...       5
# 61  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...       5
# 62  0.550725  (Test Repair, Repair (Complex), Inform User, A...       5
# 63  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...       6
# 79  0.438406  (Inform User, Repair (Simple), Analyze Defect,...       4
# 80  0.438406  (Register, Repair (Simple), Inform User, Test ...       4
# 81  0.386775  (Repair (Simple), Inform User, Test Repair, Ar...       4
# 82  0.438406  (Inform User, Repair (Simple), Register, Analy...       4
# 83  0.386775  (Inform User, Repair (Simple), Analyze Defect,...       4
# 84  0.386775  (Register, Repair (Simple), Inform User, Archi...       4
# 85  0.438406  (Register, Repair (Simple), Analyze Defect, Te...       4
# 86  0.386775  (Repair (Simple), Analyze Defect, Test Repair,...       4
# 87  0.386775  (Repair (Simple), Register, Test Repair, Archi...       4
# 88  0.386775  (Register, Repair (Simple), Analyze Defect, Ar...       4
# 89  0.438406  (Analyze Defect, Test Repair, Repair (Simple),...       5
# 90  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...       5
# 91  0.386775  (Test Repair, Repair (Simple), Inform User, Ar...       5
# 92  0.386775  (Analyze Defect, Repair (Simple), Archive Repa...       5
# 93  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...       5
# 94  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...       6

# %% [markdown]
# ### Apriori algorithm
#
# We use Repair.csv file as a data set for finding frequent item sets. Apriori algorithm is used to find frequent itemsets.

# %%
# learn to use TransactionEncoder module to convert an array to DataFrame for Apriori algorithm in mlxtend

te = TransactionEncoder()
te_ary = te.fit(data_set).transform(data_set)
data = pd.DataFrame(te_ary, columns = te.columns_)
data.tail(5)
# Out:
#       Analyze Defect  Archive Repair  Inform User  Register  Repair (Complex)  \
# 1099            True            True         True      True              True
# 1100            True            True         True      True              True
# 1101            True            True         True      True              True
# 1102            True            True         True      True              True
# 1103            True            True         True      True             False
#
#       Repair (Simple)  Restart Repair  Test Repair
# 1099            False           False         True
# 1100            False           False         True
# 1101            False           False         True
# 1102            False           False         True
# 1103             True            True         True

# %%
frequent_itemsets = apriori(data, min_support = 0.3, use_colnames = True)

# %% [markdown]
# ### Filtering data based on metrics of association rules
# In python you can filter frequent itemsets based on different metrics such as support, confidence, and lift.

# %%
# learn to use the association rule algorithm from mlxtend and filter data based on one metric.

rules_association =arule(frequent_itemsets, metric = 'lift', min_threshold = 0.8)
rules_association
# Out:
#             antecedents                                        consequents  \
# 0      (Analyze Defect)                                   (Archive Repair)
# 1      (Archive Repair)                                   (Analyze Defect)
# 2         (Inform User)                                   (Analyze Defect)
# 3      (Analyze Defect)                                      (Inform User)
# 4            (Register)                                   (Analyze Defect)
# ...                 ...                                                ...
# 1019      (Test Repair)  (Analyze Defect, Repair (Simple), Inform User,...
# 1020  (Repair (Simple))  (Analyze Defect, Test Repair, Inform User, Arc...
# 1021   (Archive Repair)  (Analyze Defect, Test Repair, Repair (Simple),...
# 1022         (Register)  (Analyze Defect, Test Repair, Repair (Simple),...
# 1023      (Inform User)  (Analyze Defect, Test Repair, Repair (Simple),...
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               1.000000            0.905797  0.905797    0.905797  1.000000
# 1               0.905797            1.000000  0.905797    1.000000  1.000000
# 2               0.998188            1.000000  0.998188    1.000000  1.000000
# 3               1.000000            0.998188  0.998188    0.998188  1.000000
# 4               1.000000            1.000000  1.000000    1.000000  1.000000
# ...                  ...                 ...       ...         ...       ...
# 1019            0.998188            0.386775  0.386775    0.387477  1.001815
# 1020            0.438406            0.905797  0.386775    0.882231  0.973983
# 1021            0.905797            0.438406  0.386775    0.427000  0.973983
# 1022            1.000000            0.386775  0.386775    0.386775  1.000000
# 1023            0.998188            0.386775  0.386775    0.387477  1.001815
#
#       leverage  conviction
# 0     0.000000    1.000000
# 1     0.000000         inf
# 2     0.000000         inf
# 3     0.000000    1.000000
# 4     0.000000         inf
# ...        ...         ...
# 1019  0.000701    1.001146
# 1020 -0.010331    0.799898
# 1021 -0.010331    0.980095
# 1022  0.000000    1.000000
# 1023  0.000701    1.001146
#
# [1024 rows x 9 columns]

# %% [markdown]
# #### Question: Change the metric to lift and support. Investigate the effect of that on the table.

# %% [markdown]
# ### Finding qualified frequent itemsets using association rules
# You can use association rules to find qualified itemsets for different datasets.

# %% [markdown]
# #### Question:  Find frequent item sets with minimum support of 0.2. Store them in frequent_itemsets variable.

# %%
#Answer
frequent_itemsets = apriori(data, min_support = 0.2, use_colnames = True)
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    1.000000                                   (Analyze Defect)
# 1    0.905797                                   (Archive Repair)
# 2    0.998188                                      (Inform User)
# 3    1.000000                                         (Register)
# 4    0.596920                                 (Repair (Complex))
# ..        ...                                                ...
# 138  0.219203  (Test Repair, Repair (Simple), Inform User, Re...
# 139  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...
# 140  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...
# 141  0.240036  (Analyze Defect, Test Repair, Archive Repair, ...
# 142  0.219203  (Analyze Defect, Test Repair, Repair (Simple),...
#
# [143 rows x 2 columns]

# %% [markdown]
# ### Filtering itemsets based on length and metrics of assosciation rules
# In this section, you will learn how to filter frequent item sets based on length of them.

# %%
# Add another column named 'length' in 'frequent_itemsets' which indicates the number of items in each frequent itemset.

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Filter out the frequent itemsets which have a length longer than 2 and a support bigger than 0.3. 

# Store these found itemsets in variable 'frequent_itemsets_filtered'.

frequent_itemsets_filtered = frequent_itemsets.loc[(frequent_itemsets['length'] > 2) & (frequent_itemsets['support'] > 0.3)]   
frequent_itemsets_filtered
# Out:
#       support                                           itemsets  length
# 34   0.905797      (Inform User, Analyze Defect, Archive Repair)       3
# 35   0.905797         (Register, Analyze Defect, Archive Repair)       3
# 36   0.550725  (Analyze Defect, Repair (Complex), Archive Rep...       3
# 37   0.386775  (Repair (Simple), Analyze Defect, Archive Repair)       3
# 39   0.905797      (Analyze Defect, Test Repair, Archive Repair)       3
# ..        ...                                                ...     ...
# 131  0.438406  (Analyze Defect, Test Repair, Repair (Simple),...       5
# 135  0.550725  (Test Repair, Repair (Complex), Inform User, A...       5
# 136  0.386775  (Test Repair, Repair (Simple), Inform User, Ar...       5
# 139  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...       6
# 140  0.386775  (Analyze Defect, Test Repair, Repair (Simple),...       6
#
# [68 rows x 3 columns]

# %% [markdown]
# ### Demonstrating selective metrics of association rules in one table
#  In this section, you will learn how to show selective metrics of association rules in one table.

# %%
# Mine association rules from the discovered frequent itemsets stored in variable 'frequent_itemsets', set minimum confidence to 0.5.

# Store the discovered rules in variable 'rules_association'.

rules_association =arule(frequent_itemsets, metric = 'confidence', min_threshold = 0.5)

# Filter out the rules with lift larger than 1 and support larger than 0.4, store the discovered rules in variable 'filtered_rules'.

filtered_rules = rules_association.loc[(rules_association['lift'] > 1) & (rules_association['support'] > 0.4)]     

# Show the columns 'antecedents', 'consequents', 'support', 'confidence' and 'lift' of variable 'filtered_rules' 

filtered_rules[['support', 'confidence', 'lift']]
# Out:
#        support  confidence      lift
# 12    0.905797    0.907441  1.001815
# 13    0.905797    1.000000  1.001815
# 16    0.550725    0.922610  1.018561
# 17    0.550725    0.608000  1.018561
# 20    0.905797    0.907441  1.001815
# ...        ...         ...       ...
# 1135  0.550725    0.551724  1.001815
# 1137  0.550725    0.551724  1.001815
# 1138  0.550725    0.922610  1.018561
# 1139  0.550725    0.608000  1.021662
# 1141  0.550725    0.551724  1.001815
#
# [441 rows x 3 columns]
